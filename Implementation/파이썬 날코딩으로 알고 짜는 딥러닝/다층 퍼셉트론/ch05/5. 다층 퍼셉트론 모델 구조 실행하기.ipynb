# %% [markdown]
# # 다층 퍼셉트론 모델 구조

# %% [markdown]
# ## 데이터 준비하기

# %% [markdown]
# ### Google Drive 연동

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Abalone 데이터

# %%
# !wget -O 'gdrive/MyDrive/ALZZA/data/abalone.csv' https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data
# Out:
# --2021-02-12 04:08:52--  https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 191873 (187K) [application/x-httpd-php]
# Saving to: ‘gdrive/MyDrive/ALZZA/data/abalone.csv’
#
# gdrive/MyDrive/ALZZ 100%[===================>] 187.38K   408KB/s    in 0.5s
#
# 2021-02-12 04:08:54 (408 KB/s) - ‘gdrive/MyDrive/ALZZA/data/abalone.csv’ saved [191873/191873]

# %% [markdown]
# ### Pulsar 데이터

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00372/HTRU2.zip
# Out:
# --2021-02-09 08:36:38--  https://archive.ics.uci.edu/ml/machine-learning-databases/00372/HTRU2.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1563015 (1.5M) [application/x-httpd-php]
# Saving to: ‘HTRU2.zip’
#
# HTRU2.zip           100%[===================>]   1.49M  3.32MB/s    in 0.4s
#
# 2021-02-09 08:36:38 (3.32 MB/s) - ‘HTRU2.zip’ saved [1563015/1563015]

# %%
# !unzip HTRU2.zip
# Out:
# Archive:  HTRU2.zip
#   inflating: HTRU_2.csv
#   inflating: HTRU_2.arff
#   inflating: Readme.txt

# %%
# !mv HTRU_2.csv gdrive/MyDrive/ALZZA/data/pulsar_stars.csv

# %% [markdown]
# ### Steel 데이터

# %%
# !wget -O gdrive/MyDrive/ALZZA/data/faults.txt https://archive.ics.uci.edu/ml/machine-learning-databases/00198/Faults.NNA
# Out:
# --2021-02-09 08:38:08--  https://archive.ics.uci.edu/ml/machine-learning-databases/00198/Faults.NNA
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 299482 (292K) [application/x-httpd-php]
# Saving to: ‘gdrive/MyDrive/ALZZA/data/faults.txt’
#
# gdrive/MyDrive/ALZZ 100%[===================>] 292.46K  1.10MB/s    in 0.3s
#
# 2021-02-09 08:38:08 (1.10 MB/s) - ‘gdrive/MyDrive/ALZZA/data/faults.txt’ saved [299482/299482]

# %%
# !wget -O gdrive/MyDrive/ALZZA/data/faults_vars.txt https://archive.ics.uci.edu/ml/machine-learning-databases/00198/Faults27x7_var
# Out:
# --2021-02-12 05:32:15--  https://archive.ics.uci.edu/ml/machine-learning-databases/00198/Faults27x7_var
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 497 [application/x-httpd-php]
# Saving to: ‘gdrive/MyDrive/ALZZA/data/faults_vars.txt’
#
# gdrive/MyDrive/ALZZ 100%[===================>]     497  --.-KB/s    in 0s
#
# 2021-02-12 05:32:16 (21.4 MB/s) - ‘gdrive/MyDrive/ALZZA/data/faults_vars.txt’ saved [497/497]

# %% [markdown]
# ### Flowers 데이터

# %% [markdown]
# #### 캐글에서 데이터 불러오기

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d alxmamaev/flowers-recognition
# Out:
# ...
#  96% 434M/450M [00:02<00:00, 186MB/s]
# 100% 450M/450M [00:02<00:00, 169MB/s]

# %%
# !mv flowers-recognition.zip gdrive/MyDrive/ALZZA/data/flowers-recognition.zip

# %%
# !unzip -qq gdrive/MyDrive/ALZZA/data/flowers-recognition.zip -d gdrive/MyDrive/ALZZA/data/

# %% [markdown]
# ## 실행하기

# %% [markdown]
# ### 구현 파일 실행시키기

# %%
# %run 'gdrive/MyDrive/ALZZA/ch05/5. 다층 퍼셉트론 모델 구조.ipynb'

# %%
# %run 'gdrive/MyDrive/ALZZA/ch05/5. 네 가지 데이터셋 파생 클래스.ipynb'

# %%
# %run 'gdrive/MyDrive/ALZZA/ch05/5. 꽃 이미지 분류 데이터셋 클래스.ipynb'

# %% [markdown]
# ### 전복 고리 수 추정 문제

# %%
ad = AbaloneDataset()
am = MlpModel('abalone_model', ad, [])
am.exec_all(epoch_count=10, report=2)
# Out:
# Model abalone_model train started:
#     Epoch 2: cost=8.191, accuracy=0.733/0.711 (0/0 secs)
#     Epoch 4: cost=7.392, accuracy=0.744/0.694 (0/0 secs)
#     Epoch 6: cost=7.247, accuracy=0.747/0.737 (0/0 secs)
#     Epoch 8: cost=7.139, accuracy=0.748/0.725 (1/1 secs)
#     Epoch 10: cost=7.054, accuracy=0.751/0.746 (0/1 secs)
# Model abalone_model train ended in 1 secs:
# Model abalone_model test report: accuracy = 0.727, (0 secs)
#
# Model abalone_model Visualization
# [0.00,0.00,1.00,0.70,0.53,0.17,1.56,0.61,0.39,0.44] => 추정 12.9 : 정답 10.0
# [0.00,1.00,0.00,0.46,0.38,0.12,0.48,0.22,0.10,0.17] => 추정  8.7 : 정답  7.0
# [0.00,0.00,1.00,0.58,0.45,0.14,1.14,0.56,0.22,0.29] => 추정 11.3 : 정답  8.0

# %% [markdown]
# ### 펄서 여부 판정 문제

# %% [markdown]
# #### 이진 분류

# %%
pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [4])
pm.exec_all()
# Out:
# Model pulsar_model train ended in 2 secs:
# Model pulsar_model test report: accuracy = 0.971, (0 secs)
#
# Model pulsar_model Visualization
# [121.8, 48.0,  0.2,...] => 추정 별(확률 0.01) : 정답 별 => O
# [143.5, 46.0, -0.3,...] => 추정 별(확률 0.00) : 정답 별 => O
# [170.4, 40.9, -0.9,...] => 추정 별(확률 0.01) : 정답 별 => O

# %%
pm.visualize(5)
# Out:
# Model pulsar_model Visualization
# [ 26.8, 27.4,  6.1,...] => 추정 펄서(확률 1.00) : 정답 펄서 => O
# [143.5, 40.5, -0.2,...] => 추정 별(확률 0.00) : 정답 별 => O
# [ 99.0, 44.0,  0.4,...] => 추정 별(확률 0.02) : 정답 별 => O
# [134.6, 50.6,  0.0,...] => 추정 별(확률 0.00) : 정답 별 => O
# [130.0, 53.9,  0.4,...] => 추정 별(확률 0.17) : 정답 별 => O

# %% [markdown]
# #### 다중 분류

# %%
psd = PulsarSelectDataset()
psm = MlpModel('pulsar_select_model', psd, [4])
psm.exec_all()
# Out:
# Model pulsar_select_model train ended in 2 secs:
# Model pulsar_select_model test report: accuracy = 0.970, (0 secs)
#
# Model pulsar_select_model Visualization
# 추정확률분포 [98, 2] => 추정 별 : 정답 별 => O
# 추정확률분포 [100, 0] => 추정 별 : 정답 별 => O
# 추정확률분포 [37,63] => 추정 펄서 : 정답 별 => X

# %% [markdown]
# ### 불량 철판 판별 문제

# %%
sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12, 7])
sm.exec_all(epoch_count=50, report=10)
# Out:
# Model steel_model train started:
#     Epoch 10: cost=1.849, accuracy=0.353/0.320 (0/0 secs)
#     Epoch 20: cost=1.784, accuracy=0.353/0.320 (1/1 secs)
#     Epoch 30: cost=1.745, accuracy=0.353/0.320 (0/1 secs)
#     Epoch 40: cost=1.721, accuracy=0.353/0.320 (0/1 secs)
#     Epoch 50: cost=1.706, accuracy=0.353/0.320 (0/1 secs)
# Model steel_model train ended in 1 secs:
# Model steel_model test report: accuracy = 0.323, (0 secs)
#
# Model steel_model Visualization
# 추정확률분포 [10,11,18, 8, 7,17,30] => 추정 Other_Faults : 정답 Bumps => X
# 추정확률분포 [10,11,18, 8, 7,17,30] => 추정 Other_Faults : 정답 Pastry => X
# 추정확률분포 [10,11,18, 8, 7,17,30] => 추정 Other_Faults : 정답 Bumps => X

# %% [markdown]
# ### 꽃 사진 분류 문제

# %%
fd = FlowersDataset()
fm = MlpModel('flowers_model_1', fd, [10])
fm.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.775, accuracy=0.244/0.260 (3/3 secs)
#     Epoch 4: cost=1.753, accuracy=0.244/0.330 (3/6 secs)
#     Epoch 6: cost=1.737, accuracy=0.244/0.270 (4/10 secs)
#     Epoch 8: cost=1.724, accuracy=0.244/0.340 (3/13 secs)
#     Epoch 10: cost=1.712, accuracy=0.244/0.320 (4/17 secs)
# Model flowers_model_1 train ended in 17 secs:
# Model flowers_model_1 test report: accuracy = 0.230, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [17,20,10,17,17,19] => 추정 dandelion : 정답 daisy => X

# %%
fm2 = MlpModel('flowers_model_2', fd, [30, 10])
fm2.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_2 train started:
#     Epoch 2: cost=1.563, accuracy=0.278/0.210 (6/6 secs)
#     Epoch 4: cost=1.416, accuracy=0.376/0.350 (7/13 secs)
#     Epoch 6: cost=1.331, accuracy=0.406/0.350 (6/19 secs)
#     Epoch 8: cost=1.287, accuracy=0.440/0.360 (7/26 secs)
#     Epoch 10: cost=1.253, accuracy=0.442/0.460 (6/32 secs)
# Model flowers_model_2 train ended in 32 secs:
# Model flowers_model_2 test report: accuracy = 0.397, (0 secs)
#
# Model flowers_model_2 Visualization
# 추정확률분포 [30,24, 1,12,11,22] => 추정 daisy : 정답 daisy => O
# 추정확률분포 [42,33, 0, 7, 3,15] => 추정 daisy : 정답 dandelion => X
# 추정확률분포 [ 1,74, 0, 3,14, 7] => 추정 dandelion : 정답 sunflower => X
